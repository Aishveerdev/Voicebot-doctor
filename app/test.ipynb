# %%
from supabase import create_client

url = "https://kbliuaafwclrzgmsgeps.supabase.co"
key = "sb_publishable_w5BXRS9IMR4pjsimGgP_UQ_d-Y2nyWg"

supabase = create_client(url, key)

response = supabase.auth.sign_in_with_oauth({
    "provider": "google"
})

print(response)
# Out:
# provider='google' url='https://kbliuaafwclrzgmsgeps.supabase.co/auth/v1/authorize?code_challenge=fggrjbMp-qbI2e9K3zNnlxVQvY6Ma0mBNGBahUk3tyc&code_challenge_method=s256&provider=google'
